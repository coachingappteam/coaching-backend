# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
results = pd.read_csv("output_M_LCM.tsv", sep='\t')
results.head()
dates = pd.read_csv("competitions_dates_M_LCM.tsv", sep='\t')
dates.head()
# Out:
#    Distance  Meet  Year                      Competition   Time
# 0        50  Free  2009               2009 Bulgaria Open  23.76
# 1        50  Free  2009                 USC Invitational  24.24
# 2        50  Free  2009        Southern Cal Invitational  24.24
# 3        50  Free  2009  2009 Iowa Swimming Summer State  24.39
# 4        50  Free  2009               2009 Bulgaria Open  24.44
#    Year                            Competition                          Dates
# 0  2009                     2009 Bulgaria Open               Jul. 10–12, 2009
# 1  2009                       USC Invitational               Oct. 09–10, 2009
# 2  2009              Southern Cal Invitational               Oct. 09–10, 2009
# 3  2009        2009 Iowa Swimming Summer State  Jul. 30, 2009 - Aug. 02, 2009
# 4  2009  2009 Bulgaria Boys Girls Senior Youth               Jul. 03–05, 2009

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
dates["Parsed_Dates"] = dates["Dates"].str.lower()

dates["Parsed_Dates"] = dates["Parsed_Dates"].str.replace(r'–.+', "")
dates["Parsed_Dates"] = dates["Parsed_Dates"].str.replace(r'-.+', "")
for month in months:
    
    month_cdf = dates["Parsed_Dates"].str.lower().str.contains(month.lower())
    month_ddf =  ""
    month_df = dates[month_cdf]
    month_df.head()
# Out:
#     Year                                        Competition             Dates  \
# 19  2010              UALR vs. North Texas, Henderson State     Jan. 06, 2010
# 39  2011                            Loras vs. East Carolina     Jan. 01, 2011
# 42  2012                     Victorian Winter Championships  Jan. 13–15, 2012
# 49  2012                                 Florida vs. Auburn     Jan. 21, 2012
# 92  2013  Saint Marys College of Maryland vs. Mary Washi...     Jan. 10, 2013
#
#      Parsed_Dates
# 19  jan. 06, 2010
# 39  jan. 01, 2011
# 42        jan. 13
# 49  jan. 21, 2012
# 92  jan. 10, 2013
#     Year                                        Competition             Dates  \
# 12  2010         Last Chance Meet: Mountain West Conference     Feb. 28, 2010
# 14  2010            Last Chance Meet: Georgia - Long Course     Feb. 28, 2010
# 26  2011           Missouri Grand Prix (College Teams Only)  Feb. 18–21, 2011
# 34  2011                 MWC Last Chance Meet - Long Course     Feb. 27, 2011
# 63  2012  USA Swimming Grand Prix - Missouri (18 & Under...  Feb. 10–12, 2012
#
#      Parsed_Dates
# 12  feb. 28, 2010
# 14  feb. 28, 2010
# 26        feb. 18
# 34  feb. 27, 2011
# 63        feb. 10
#     Year                                   Competition             Dates  \
# 13  2010    2010 Speedo Champions Series - Minneapolis  Mar. 10–13, 2010
# 16  2010                       2010 Bulgaria Men Women  Mar. 19–21, 2010
# 18  2010             Last Chance Meet: Ohio State - LC     Mar. 07, 2010
# 24  2011     2011 Speedo Sectionals - Indianapolis, IN  Mar. 24–27, 2011
# 28  2011  2011 Speedo Sectionals - Fort Lauderdale, FL  Mar. 17–20, 2011
#
#      Parsed_Dates
# 13        mar. 10
# 16        mar. 19
# 18  mar. 07, 2010
# 24        mar. 24
# 28        mar. 17
#      Year                                        Competition  \
# 97   2014                       2014 Arena Grand Prix - Mesa
# 161  2015                  Irish Open Swimming Championships
# 240  2016  2016 CA TYR/MVN Fran Crippen Swim Meet of Cham...
# 306  2016               Irish Long Course Championships 2016
# 315  2016                     2016 ST ASC Tax Refund Round U
#
#                              Dates    Parsed_Dates
# 97                Apr. 24–26, 2014         apr. 24
# 161  Apr. 30, 2015 - May. 03, 2015  apr. 30, 2015
# 240  Apr. 28, 2016 - May. 01, 2016  apr. 28, 2016
# 306  Apr. 28, 2016 - May. 01, 2016  apr. 28, 2016
# 315               Apr. 15–17, 2016         apr. 15
#      Year                                Competition             Dates  \
# 118  2014      2014 South Texas End of School Invite  May. 16–18, 2014
# 201  2015          Dallas Mustangs Senior Circuit #1  May. 29–31, 2015
# 219  2016  2016 NOVAQUATICS – SPEEDO GRAND CHALLENGE  May. 27–29, 2016
# 220  2016    2016 Arena Pro Swim Series at Charlotte  May. 12–15, 2016
# 234  2016      Atviras Lietuvos plaukimo čempionatas  May. 26–28, 2016
#
#     Parsed_Dates
# 118      may. 16
# 201      may. 29
# 219      may. 27
# 220      may. 12
# 234      may. 26
#     Year                                        Competition  \
# 5   2009                    2009 Bulgaria Boys Girls Junior
# 41  2012                            USA Olympic Team Trials
# 46  2012  2012 United States Olympic Team Trials - 18 & ...
# 59  2012  2012 United States Olympic Team Trials - 18 & ...
# 70  2012                         MT MAC Firecracker Classic
#
#                             Dates    Parsed_Dates
# 5                Jun. 26–28, 2009         jun. 26
# 41  Jun. 25, 2012 - Jul. 02, 2012  jun. 25, 2012
# 46  Jun. 25, 2012 - Jul. 02, 2012  jun. 25, 2012
# 59  Jun. 25, 2012 - Jul. 02, 2012  jun. 25, 2012
# 70               Jun. 21–24, 2012         jun. 21
#    Year                                Competition  \
# 0  2009                         2009 Bulgaria Open
# 3  2009            2009 Iowa Swimming Summer State
# 4  2009      2009 Bulgaria Boys Girls Senior Youth
# 6  2010      2010 Speedo Champions Series - Athens
# 8  2010  2010 Speedo Champions Series - California
#
#                            Dates    Parsed_Dates
# 0               Jul. 10–12, 2009         jul. 10
# 3  Jul. 30, 2009 - Aug. 02, 2009  jul. 30, 2009
# 4               Jul. 03–05, 2009         jul. 03
# 6               Jul. 15–18, 2010         jul. 15
# 8                  Jul. 24, 2010   jul. 24, 2010
#     Year                                        Competition             Dates  \
# 7   2010                 2010 Junior National Championships  Aug. 09–13, 2010
# 9   2010                    2010 YMCA Long Course Nationals     Aug. 02, 2010
# 10  2010            2010 Speedo Champions Series - Mt. Hood     Aug. 02, 2010
# 11  2010  2010 Speedo Champions Series - Gainesville (Be...     Aug. 02, 2010
# 23  2011                 2011 USA Swimming Junior Nationals  Aug. 08–12, 2011
#
#      Parsed_Dates
# 7         aug. 09
# 9   aug. 02, 2010
# 10  aug. 02, 2010
# 11  aug. 02, 2010
# 23        aug. 08
#      Year                          Competition                          Dates  \
# 108  2014          Victorian Age Championships               Sep. 05–07, 2014
# 209  2015          Cleveland State Splash Bash                  Sep. 26, 2015
# 279  2016    NCSA Summer Swimming Championship  Sep. 27, 2016 - Aug. 13, 2016
# 334  2016  Michigan State vs. Iowa, Notre Dame                  Sep. 30, 2016
# 557  2017  New Zealand Secondary School Champs               Sep. 15–17, 2017
#
#        Parsed_Dates
# 108         sep. 05
# 209   sep. 26, 2015
# 279  sep. 27, 2016
# 334   sep. 30, 2016
# 557         sep. 15
#      Year                                  Competition             Dates  \
# 1    2009                             USC Invitational  Oct. 09–10, 2009
# 2    2009                    Southern Cal Invitational  Oct. 09–10, 2009
# 32   2011                          Florida vs. Georgia     Oct. 28, 2011
# 33   2011  Michigan State vs. Cleveland State, Oakland     Oct. 08, 2011
# 127  2014                2014 Gulf Open Water Swimming     Oct. 05, 2014
#
#       Parsed_Dates
# 1          oct. 09
# 2          oct. 09
# 32   oct. 28, 2011
# 33   oct. 08, 2011
# 127  oct. 05, 2014
#      Year                             Competition             Dates  \
# 27   2011                  Tennessee Invitational  Nov. 16–18, 2011
# 31   2011                 Pittsburgh Invitational  Nov. 18–20, 2011
# 35   2011  Navy vs. American, Bucknell, Lafayette     Nov. 05, 2011
# 121  2014             Clarkson vs. Saint Michaels     Nov. 15, 2014
# 135  2015                  Tennessee Invitational  Nov. 20–23, 2015
#
#       Parsed_Dates
# 27         nov. 16
# 31         nov. 18
# 35   nov. 05, 2011
# 121  nov. 15, 2014
# 135        nov. 20
#      Year                                     Competition             Dates  \
# 25   2011  2012 AT&T National Championships (18 & Unders)  Dec. 01–03, 2011
# 36   2011                       Cal Poly vs. UC-San Diego     Dec. 18, 2011
# 45   2012                     Victorian Age Championships  Dec. 18–23, 2012
# 90   2013              Delta State Christmas Invitational  Dec. 14–17, 2013
# 123  2014                        Delta State Invitational  Dec. 13–16, 2014
#
#       Parsed_Dates
# 25         dec. 01
# 36   dec. 18, 2011
# 45         dec. 18
# 90         dec. 14
# 123        dec. 13

# %%
years = {}
for year in range(2009, 2020):
    years[str(year)] = results["Year"] == year
    
years["2009"].head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Year, dtype: bool

# %%
competitions_per_year = {}
for year in range(2009, 2020):
    competitions_per_year[str(year)] = results[years[str(year)]]["Competition"].drop_duplicates(keep ='first')

# %%
competitions_per_year["2011"]
# Out:
# 16935               2011 Speedo Sectionals - Fresno, CA
# 16937                2011 USA Swimming Junior Nationals
# 16941         2011 Speedo Sectionals - Indianapolis, IN
# 16942    2012 AT&T National Championships (18 & Unders)
# 16943          Missouri Grand Prix (College Teams Only)
# 16945                            Tennessee Invitational
# 16971      2011 Speedo Sectionals - Fort Lauderdale, FL
# 16987            2011 Speedo Sectionals - Oklahoma City
# 16990                           2011 Bulgaria Men Women
# 17003                           Pittsburgh Invitational
# 17043                               Florida vs. Georgia
# 17087       Michigan State vs. Cleveland State, Oakland
# 17109                MWC Last Chance Meet - Long Course
# 17144            Navy vs. American, Bucknell, Lafayette
# 17146                         Cal Poly vs. UC-San Diego
# 17299                    2011 Bulgaria Boys Girls Youth
# 17884                              2011 Bulgaria Junior
# 17985                           Loras vs. East Carolina
# 18126                               2011 Bulgaria Detsa
# Name: Competition, dtype: object

# %%
# competitions = list(map(lambda x:x, competitions.keys()))
# competitions
with open("competitions_M_LCM.tsv", "w+", encoding="utf-8") as out:
    for year in range(2009,2020):
        for comp in competitions_per_year[str(year)]:
            out.write("{0}\t{1}\n".format(comp, year))

# %%
competitions_df = pd.read_csv("competitions_M_LCM.tsv", sep='\t')
competitions_df.head()
# Out:
#                              Competition  Year
# 0                     2009 Bulgaria Open  2009
# 1                       USC Invitational  2009
# 2              Southern Cal Invitational  2009
# 3        2009 Iowa Swimming Summer State  2009
# 4  2009 Bulgaria Boys Girls Senior Youth  2009

# %%
standard_times_df = pd.read_csv("Swimming Standard Times.csv")
standard_times_df.head()
# Out:
#       Event Amateur Intermediate Upper Intermediate Lower Professional
# 0   50 Free      26                 26                 23           23
# 1  100 Free      58                 58                 52           52
# 2  200 Free    2:01               2:01               1:52         1:52
# 3  400 Free    4:30               4:30               4:00         4:00
# 4  800 Free    9:50               9:15               8:12         8:12

# %%
free = results["Meet"] == 'Free'
free_df = results[free]


free_50 = free_df["Distance"] == 50
free_50_df = free_df[free_50]
free_50_df["Time_Numeric"] = pd.to_timedelta(free_50_df["Time"], unit="sec", errors="ignore")
free_50_df.sort_values(by=["Time_Numeric"])
free_50_df.head()
# Out:
# c:\users\luisr\miniconda3\envs\coaching-env\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#         Distance  Meet  Year                                    Competition  \
# 18278         50  Free  2011            2011 Speedo Sectionals - Fresno, CA
# 336147        50  Free  2019                  18th FINA World Championships
# 266682        50  Free  2017                  17th FINA World Championships
# 336148        50  Free  2019                  18th FINA World Championships
# 136889        50  Free  2015  16th FINA World Championships - Kazan, Russia
# ...          ...   ...   ...                                            ...
# 392           50  Free  2009                2009 Iowa Swimming Summer State
# 393           50  Free  2009                2009 Iowa Swimming Summer State
# 18277         50  Free  2011                            2011 Bulgaria Detsa
# 394           50  Free  2009                2009 Iowa Swimming Summer State
# 18279         50  Free  2011                         Tennessee Invitational
#
#            Time Time_Numeric
# 18278   1:02.84      1:02.84
# 336147    21.04        21.04
# 266682    21.15        21.15
# 336148    21.18        21.18
# 136889    21.19        21.19
# ...         ...          ...
# 392       49.59        49.59
# 393       50.03        50.03
# 18277     50.70        50.70
# 394       52.14        52.14
# 18279   9:59.99      9:59.99
#
# [26604 rows x 6 columns]
#    Distance  Meet  Year                      Competition   Time Time_Numeric
# 0        50  Free  2009               2009 Bulgaria Open  23.76        23.76
# 1        50  Free  2009                 USC Invitational  24.24        24.24
# 2        50  Free  2009        Southern Cal Invitational  24.24        24.24
# 3        50  Free  2009  2009 Iowa Swimming Summer State  24.39        24.39
# 4        50  Free  2009               2009 Bulgaria Open  24.44        24.44

# %%
from datetime import timedelta
def to_timedelta(s):
    split = s.split(":")
    hours = 0
    minutes = 0
    seconds = ""
    milliseconds = 0
    if len(split) == 3:
        hours = int(split[0])
        minutes = int(split[1])
        seconds = split[2]
    elif len(split) == 2:
        minutes = int(split[0])
        seconds = split[1]
    else:
        seconds = split[0]
    seconds_split = seconds.split(".")
    if len(seconds_split) == 2:
        if len(seconds_split[1]) == 1:
            milliseconds = int(seconds_split[1])*100
        elif len(seconds_split[1]) == 2:
            milliseconds = int(seconds_split[1])*10
        else:
            milliseconds = int(seconds_split[1])
        return timedelta(hours=hours, minutes=minutes, seconds=int(seconds_split[0]), milliseconds=milliseconds)
    else:
        return timedelta(hours=hours, minutes=minutes, seconds=int(seconds_split[0]))

# %%
standard_times_df["Amateur"] = standard_times_df["Amateur"].apply(to_timedelta)
standard_times_df["Intermediate Upper"] = standard_times_df["Intermediate Upper"].apply(to_timedelta)
standard_times_df["Intermediate Lower"] = standard_times_df["Intermediate Lower"].apply(to_timedelta)
standard_times_df["Professional"] = standard_times_df["Professional"].apply(to_timedelta)
standard_times_df.head()
# Out:
#       Event  Amateur Intermediate Upper Intermediate Lower Professional
# 0   50 Free 00:00:26           00:00:26           00:00:23     00:00:23
# 1  100 Free 00:00:58           00:00:58           00:00:52     00:00:52
# 2  200 Free 00:02:01           00:02:01           00:01:52     00:01:52
# 3  400 Free 00:04:30           00:04:30           00:04:00     00:04:00
# 4  800 Free 00:09:50           00:09:15           00:08:12     00:08:12

# %%
results_td = results
results_td["Time"] = results_td["Time"].apply(to_timedelta)
results_td.head()
# Out:
#    Distance  Meet  Year                      Competition            Time
# 0        50  Free  2009               2009 Bulgaria Open 00:00:23.760000
# 1        50  Free  2009                 USC Invitational 00:00:24.240000
# 2        50  Free  2009        Southern Cal Invitational 00:00:24.240000
# 3        50  Free  2009  2009 Iowa Swimming Summer State 00:00:24.390000
# 4        50  Free  2009               2009 Bulgaria Open 00:00:24.440000

# %%
def label_skills(row):
#     print("{0} {1}".format(row[0], row[1]))
    event = standard_times_df["Event"] == row[5]
    event_df = standard_times_df[event]
#     print(len(event_df["Amateur"]))
    event_df = event_df.reset_index()
    amateur_time = event_df["Amateur"][0]
    pro_time = event_df["Professional"][0]
    if row[4] > amateur_time:
        return 1
    elif row[4] <= pro_time:
        return 3
    return 2

def merge_distance_meet(row):
    return "{0} {1}".format(row[0], row[1])

def form_str(row):
    event = re.sub("Fly", "Butterfly", row)
    return event

# %%
events_codes = pd.read_csv("Events.csv", index_col="Event", squeeze=True)
# results_td["Event"] = results_td["Event"].apply(form_str)
# results_td["Event"] = results_td["Event"].map(events_codes)
# results_td.head()
# standard_times_df["Event"] = standard_times_df["Event"].map(events_codes)

results_td = pd.read_csv("results_td.csv")

# results_td["Event"] = results_td.apply(merge_distance_meet, axis=1)
# results_d = results_td["Event"].isin(standard_times_df["Event"])
# keys = list(standard_times_df["Event"].columns.values)
# i1 = df1.set_index(keys).index
# i2 = df2.set_index(keys).index
# results_td_new = 
# results_td[results_d].head()


results_td = results_td[results_td["Event"] >= 0]

results_td["Skill_Level"] = results_td.apply(label_skills, axis=1)
results_td.head()
# Out:
#    Distance  Meet  Year                      Competition            Time  \
# 0        50  Free  2009               2009 Bulgaria Open 00:00:23.760000
# 1        50  Free  2009                 USC Invitational 00:00:24.240000
# 2        50  Free  2009        Southern Cal Invitational 00:00:24.240000
# 3        50  Free  2009  2009 Iowa Swimming Summer State 00:00:24.390000
# 4        50  Free  2009               2009 Bulgaria Open 00:00:24.440000
#
#    Event  Skill_Level
# 0    0.0            2
# 1    0.0            2
# 2    0.0            2
# 3    0.0            2
# 4    0.0            2

# %%
# results_td["Split_Mean"] =  results_(results_td["Distance"]/50)
def get_split_mean(row):
    laps = row[0] / 50
    time = row[4]
    mean_time = time / laps
    return  laps

results_td["Reps"] = results_td.apply(get_split_mean, axis=1)

# results_td["Time"][0] / 1
results_td.tail()
# Out:
#         Distance Meet  Year  \
# 387680       400   IM  2019
# 387681       400   IM  2019
# 387682       400   IM  2019
# 387683       400   IM  2019
# 387684       400   IM  2019
#
#                                               Competition            Time  \
# 387680                           ST TXLA Long Course TAGS 00:04:42.820000
# 387681          Scottish National Age Group Championships 00:04:42.830000
# 387682  Campeonatos Nacionais Juvenis e Absolutos de P... 00:04:42.830000
# 387683           Central Zone (WI) Age Group Championship 00:04:42.840000
# 387684                 VA TIDE Speedo Red, White and Blue 00:04:42.840000
#
#         Event  Skill_Level      Split_Mean  Reps
# 387680   16.0            2 00:00:35.352500   8.0
# 387681   16.0            2 00:00:35.353750   8.0
# 387682   16.0            2 00:00:35.353750   8.0
# 387683   16.0            2 00:00:35.355000   8.0
# 387684   16.0            2 00:00:35.355000   8.0

# %%
fre.sort_values(by=["Meet"])
fre.head()
# Out:
#         Distance  Meet  Year  \
# 0             50  Free  2009
# 266890        50  Free  2017
# 266889        50  Free  2017
# 266888        50  Free  2017
# 266887        50  Free  2017
# ...          ...   ...   ...
# 97430         50  Free  2014
# 97429         50  Free  2014
# 97428         50  Free  2014
# 97438         50  Free  2014
# 339177        50  Free  2019
#
#                                               Competition   Time  \
# 0                                      2009 Bulgaria Open  23.76
# 266890               Arena Pro Swim Series - Indianapolis  22.68
# 266889                         NC MAC Charlotte Ultraswim  22.67
# 266888                         NC MAC Charlotte Ultraswim  22.67
# 266887  2017 Hancock Prospecting Australian Championships  22.67
# ...                                                   ...    ...
# 97430   2014 Speedo Champions Series LCM - Greensboro, NC  23.82
# 97429     2014 Speedo Champions Series LCM - Columbia, MO  23.82
# 97428     2014 Speedo Champions Series LCM - Columbia, MO  23.82
# 97438    2014 Speedo Champions Series LCM - Iowa City, IA  23.83
# 339177  Florida Swimming Senior Long Course Championships  23.94
#
#           Time_Numeric  Skill_Level    Zscore  seconds
# 0      00:00:23.760000            2  0.978360    23.76
# 266890 00:00:22.680000            3  1.006845    22.68
# 266889 00:00:22.670000            3  1.006401    22.67
# 266888 00:00:22.670000            3  1.006401    22.67
# 266887 00:00:22.670000            3  1.006401    22.67
# ...                ...          ...       ...      ...
# 97430  00:00:23.820000            2  0.980831    23.82
# 97429  00:00:23.820000            2  0.980831    23.82
# 97428  00:00:23.820000            2  0.980831    23.82
# 97438  00:00:23.830000            2  0.981242    23.83
# 339177 00:00:23.940000            2  0.985772    23.94
#
# [26604 rows x 9 columns]
#    Distance  Meet  Year                      Competition   Time  \
# 0        50  Free  2009               2009 Bulgaria Open  23.76
# 1        50  Free  2009                 USC Invitational  24.24
# 2        50  Free  2009        Southern Cal Invitational  24.24
# 3        50  Free  2009  2009 Iowa Swimming Summer State  24.39
# 4        50  Free  2009               2009 Bulgaria Open  24.44
#
#      Time_Numeric  Skill_Level    Zscore  seconds
# 0 00:00:23.760000            2  0.978360    23.76
# 1 00:00:24.240000            2  0.998125    24.24
# 2 00:00:24.240000            2  0.998125    24.24
# 3 00:00:24.390000            2  1.004301    24.39
# 4 00:00:24.440000            2  1.006360    24.44

# %%
# fre[["Distance", "Meet", "seconds", "Skill_Level"]][fre["Skill_Level"] == 1].to_csv("testing_with_skills_1.csv")

amateurs = fre[["Distance", "Meet", "seconds", "Skill_Level"]][fre["Skill_Level"] == 1]

intermediates = fre[["Distance", "Meet", "seconds", "Skill_Level"]][fre["Skill_Level"] == 2]

pros = fre[["Distance", "Meet", "seconds", "Skill_Level"]][fre["Skill_Level"] == 3]

a_ax = amateurs["seconds"].plot.kde()
a_ax.set_xlim(left=15, right=35)
amateurs_std = amateurs.seconds.std(axis=0, skipna=True)
amateurs_mean = amateurs.seconds.mean()
round(amateurs_mean + amateurs_std, 2)

i_ax = intermediates["seconds"].plot.kde()
i_ax.set_xlim(left=15, right=35)
intermediates_std = intermediates.seconds.std(axis=0, skipna=True)
intermediates_mean = intermediates.seconds.mean()
round(intermediates_mean + intermediates_std, 2)

p_ax = pros["seconds"].plot.kde()
p_ax.set_xlim(left=15, right=35)
pros_std = pros.seconds.std(axis=0, skipna=True)
pros_mean = pros.seconds.mean()
round(pros_mean + pros_std, 2)








# a_ax
i_ax
# p_ax
# x, y = ecdf(amateurs["seconds"])
# plt.figure(figsize=(8,7))
# sns.set()
# plt.plot(x, y, marker=".", linestyle="none")
# plt.xlabel("Elapsed Time (s)")
# plt.ylabel("Cumulative Distribution Function")




# fre["seconds"] = fre.Time_Numeric.dt.total_seconds()
# fre.head()
# fre.sort_values(by=["seconds"])

# # val = fre[["Distance", "Meet", "Time_Numeric", "Skill_Level"]][fre["Skill_Level"] == 1]
# fre['Zscore'] = fre.groupby('Skill_Level').seconds.apply(lambda x: x.div(x.mean()))
# fre.groupby('Skill_Level').Zscore.plot.kde()

# g = fre.groupby('Skill_Level').Zscore
# n = g.ngroups
# fig, axes = plt.subplots(n // 2, 2, figsize=(6, 6), sharex=True, sharey=True)
# for i, (name, group) in enumerate(g):
#     r, c = i // 2, i % 2
#     group.plot.kde(title=name, ax=axes[r, c])
# fig.tight_layout()
# Out:
# (15, 35)
# 38.67
# (15, 35)
# 25.02
# (15, 35)
# 22.92

# %%
# results_td[results_td["Meet"].str.contains("Free")]["Distance"].mean()

# %%
free_50_df["Time_Numeric"] = free_50_df["Time"].apply(to_timedelta)
free_50_df.head()
# Out:
# c:\users\luisr\miniconda3\envs\coaching-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Distance  Meet  Year                      Competition   Time  \
# 0        50  Free  2009               2009 Bulgaria Open  23.76
# 1        50  Free  2009                 USC Invitational  24.24
# 2        50  Free  2009        Southern Cal Invitational  24.24
# 3        50  Free  2009  2009 Iowa Swimming Summer State  24.39
# 4        50  Free  2009               2009 Bulgaria Open  24.44
#
#      Time_Numeric
# 0 00:00:23.760000
# 1 00:00:24.240000
# 2 00:00:24.240000
# 3 00:00:24.390000
# 4 00:00:24.440000

# %%
free_50_df.sort_values(by=["Time_Numeric"])
free_50_df.head()
# Out:
#         Distance  Meet  Year                                    Competition  \
# 336147        50  Free  2019                  18th FINA World Championships
# 266682        50  Free  2017                  17th FINA World Championships
# 336148        50  Free  2019                  18th FINA World Championships
# 136889        50  Free  2015  16th FINA World Championships - Kazan, Russia
# 266683        50  Free  2017                  17th FINA World Championships
# ...          ...   ...   ...                                            ...
# 393           50  Free  2009                2009 Iowa Swimming Summer State
# 18277         50  Free  2011                            2011 Bulgaria Detsa
# 394           50  Free  2009                2009 Iowa Swimming Summer State
# 18278         50  Free  2011            2011 Speedo Sectionals - Fresno, CA
# 18279         50  Free  2011                         Tennessee Invitational
#
#            Time    Time_Numeric
# 336147    21.04 00:00:21.040000
# 266682    21.15 00:00:21.150000
# 336148    21.18 00:00:21.180000
# 136889    21.19 00:00:21.190000
# 266683    21.27 00:00:21.270000
# ...         ...             ...
# 393       50.03 00:00:50.030000
# 18277     50.70 00:00:50.700000
# 394       52.14 00:00:52.140000
# 18278   1:02.84 00:01:02.840000
# 18279   9:59.99 00:09:59.990000
#
# [26604 rows x 6 columns]
#    Distance  Meet  Year                      Competition   Time  \
# 0        50  Free  2009               2009 Bulgaria Open  23.76
# 1        50  Free  2009                 USC Invitational  24.24
# 2        50  Free  2009        Southern Cal Invitational  24.24
# 3        50  Free  2009  2009 Iowa Swimming Summer State  24.39
# 4        50  Free  2009               2009 Bulgaria Open  24.44
#
#      Time_Numeric
# 0 00:00:23.760000
# 1 00:00:24.240000
# 2 00:00:24.240000
# 3 00:00:24.390000
# 4 00:00:24.440000
